# %% [markdown]
# # NLP TP2: Introduction to maths optimization

# %% [markdown]
# # Alexis Vannson

# %% [markdown]
# ### **Exercise 1**: Function Plotting and Analytical Determination of Critical Points

# %%
# Import numpy and pyplot libraries
import numpy as np
import math 
import matplotlib.pyplot as plt

# %%
def f1(x, y):
    return x**3 + y**3 - 3*x - 12*y

def f2(x, y):
    return x**3 - 12*x*y + 8*y**3

def f3(x, y):
    return (x - 1)**2 + 10 * (x**2 - y)**2

# %% [markdown]
# ### **Exercise 2:** Plotting Function Graphs

# %% [markdown]
# 2.1 The instruction blocks below allow you to plot the graph of the function $f_1(x,y)$ for $x \in [-4,4]$ and different fixed values of y.
#
# Execute the different instruction blocks, then analyze what each line does.
#
# Subsequently, you will rely on this example to plot function graphs.

# %%
# Definition of the plotting domain
xmin, xmax, nx = -4, 4, 41
ymin, ymax, ny = -4, 4, 41
# Discretization of the plotting domain
x1d = np.linspace(xmin,xmax,nx)
y1d = np.linspace(ymin,ymax,ny)
x2d, y2d = np.meshgrid(x1d, y1d)

# Plot contour lines (isovalues) of f1
nIso = 21
plt.contour(x2d,y2d,f2(x2d,y2d),nIso)
plt.title('Contour Lines')
plt.xlabel('x values')
plt.ylabel('y values')
plt.grid()
plt.axis('square')
# Out:
# (-4.0, 4.0, -4.0, 4.0)

# %%
# Definition of the plotting domain
xmin, xmax, nx = -4, 4, 41
ymin, ymax, ny = -4, 4, 41
# Discretization of the plotting domain
x1d = np.linspace(xmin,xmax,nx)
y1d = np.linspace(ymin,ymax,ny)
x2d, y2d = np.meshgrid(x1d, y1d)

# Plot contour lines (isovalues) of f1
nIso = 21
plt.contour(x2d,y2d,f3(x2d,y2d),nIso)
plt.title('Contour Lines')
plt.xlabel('x values')
plt.ylabel('y values')
plt.grid()
plt.axis('square')
# Out:
# (-4.0, 4.0, -4.0, 4.0)

# %%
# Create array of x samples
xmin, xmax, nx = -4, 4, 41
tab_x = np.linspace(xmin,xmax,nx)
# Calculate values of f(x,y) for x values in tab_x and different y values
tab_zm2 = f1(tab_x,-2)
tab_z0 = f1(tab_x,0)
tab_zp2 = f1(tab_x,2)
# Plot the graph
plt.plot(tab_x, tab_zm2,'k-',label='y = -2')
plt.plot(tab_x, tab_z0,'r-',label='y = 0')
plt.plot(tab_x, tab_zp2,'b-',label='y = +2')
plt.xlabel('x values')
plt.ylabel('f1(x,y=constant) values')
plt.legend()
plt.grid()

# %% [markdown]
# 2.2 Plot the graph of the function $f_1(x,y)$ for $y \in [-4,4]$ and different fixed values of x.

# %%
# Create array of y samples
ymin, ymax, ny = -4, 4, 41
tab_y = np.linspace(ymin,ymax,ny)
# Calculate values of f(x,y) for y values in tab_y and different x values
tab_zm2 = f1(-2,tab_y)
tab_z0 = f1(0,tab_y)
tab_zp2 = f1(2,tab_y)
# Plot the graph
plt.plot(tab_y, tab_zm2,'k-',label='x = -2')
plt.plot(tab_y, tab_z0,'r-',label='x = 0')
plt.plot(tab_y, tab_zp2,'b-',label='x = +2')
plt.xlabel('y values')
plt.ylabel('f1(x=constant,y) values')
plt.legend()
plt.grid()

# %% [markdown]
# 2.3 Plot the graph of the function $f_1(x,\alpha .x)$ for $x \in [-3,3]$ and $\alpha \in \{ 1/\sqrt3, 1, \sqrt3 \}$. What do these graphs represent?

# %%
# Create array of x samples
xmin, xmax, nx = -4, 4, 41
tab_x = np.linspace(xmin,xmax,nx)
# Calculate values of f(x,y) for x values in tab_x and different y values
tab_zm2 = f1(tab_x,tab_x*(1/math.sqrt(3)))
tab_z0 = f1(tab_x,tab_x)
tab_zp2 = f1(tab_x,tab_x*math.sqrt(3))
# Plot the graph
plt.plot(tab_x, tab_zm2,'k-',label='alpha =1/√3')
plt.plot(tab_x, tab_z0,'r-',label='alpha =1')
plt.plot(tab_x, tab_zp2,'b-',label='alpha = √3')
plt.xlabel('x values')
plt.ylabel('f1(x,y) values')
plt.legend()
plt.grid()

# %% [markdown]
# ### **Exercise 3:** Plotting Contour Lines (Isovalues) of a Function of Two Variables

# %% [markdown]
# 3.1 The instruction block below allows you to plot the contour lines (isovalues) of the function $f_1(x,y)$ for $x \in [-4,4]$ and $y \in [-4,4]$.
#
# Execute the instruction block, then analyze what each line does.
#
# Vary the different plotting parameters (intervals of x and y, number of discretization points, number of contour lines) and analyze their influence. In particular, what happens if the domain discretization is insufficient?
#
# Subsequently, you will rely on this example to plot function contour lines.

# %%
# Definition of the plotting domain
xmin, xmax, nx = -4, 4, 41
ymin, ymax, ny = -4, 4, 41
# Discretization of the plotting domain
x1d = np.linspace(xmin,xmax,nx)
y1d = np.linspace(ymin,ymax,ny)
x2d, y2d = np.meshgrid(x1d, y1d)

# Plot contour lines (isovalues) of f1
nIso = 21
plt.contour(x2d,y2d,f1(x2d,y2d),nIso)
plt.title('Contour Lines')
plt.xlabel('x values')
plt.ylabel('y values')
plt.grid()
plt.axis('square')
# Out:
# (-4.0, 4.0, -4.0, 4.0)

# %% [markdown]
# 3.2 On the contour line representation of $f_1$, locate the critical points calculated in exercise 1. It will likely be necessary to adjust the contour plot parameters.

# %%
# Critical points of f1 found analytically
crit_f1 = [(-1,-2), (-1,2), (1,-2), (1,2)]

# Plot contours and critical points
plt.figure(figsize=(6,6))
plt.contour(x2d, y2d, f1(x2d, y2d), 21)
plt.title("Contour Lines of f1 with Critical Points")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.axis('square')

# Mark critical points
for (x, y) in crit_f1:
    plt.plot(x, y, 'ro', markersize=6)
    plt.text(x+0.15, y+0.15, f"({x},{y})", color='red')

plt.show()

# %% [markdown]
# 3.3 The instruction block below provides the template for the function df1, which calculates and returns the gradient of $f_1$. Complete this instruction block so that df1 does what is expected. Then use this function to verify that the gradient of $f_1$ is indeed zero at the critical points.

# %%
# Gradient of f1
def df1(x, y):
    df_dx = 3*x**2 - 3
    df_dy = 3*y**2 - 12
    return np.array([df_dx, df_dy])

# Check gradient at critical points
for (x, y) in crit_f1:
    print(f"Gradient at ({x},{y}) = {df1(x,y)}")
# Out:
# Gradient at (-1,-2) = [0 0]
# Gradient at (-1,2) = [0 0]
# Gradient at (1,-2) = [0 0]
# Gradient at (1,2) = [0 0]

# %% [markdown]
# 3.4 The instruction block below provides the template for the function d2f1, which calculates and returns the Hessian matrix of $f_1$. Complete this instruction block so that d2f1 does what is expected. Then use this function to verify the nature of the critical points of $f_1$.

# %%
# Instruction block to be completed
# Hessian of f1
def d2f1(x, y):
    d2f_dxdx = 6*x
    d2f_dxdy = 0
    d2f_dydx = 0
    d2f_dydy = 6*y
    return np.array([[d2f_dxdx, d2f_dxdy],
                     [d2f_dydx, d2f_dydy]])

# Classify critical points using eigenvalues
for (x, y) in crit_f1:
    H = d2f1(x, y)
    eigs = np.linalg.eigvals(H)
    print(f"Point ({x},{y}) -> eigenvalues = {eigs}")
# Out:
# Point (-1,-2) -> eigenvalues = [ -6. -12.]
# Point (-1,2) -> eigenvalues = [-6. 12.]
# Point (1,-2) -> eigenvalues = [  6. -12.]
# Point (1,2) -> eigenvalues = [ 6. 12.]

# %%
# Template for calculating eigenvalues of a matrix, to be adapted:
matrice = [[1,2],[3,4]]
valProp = np.linalg.eigvals(matrice)
print('Eigenvalues of the matrix {} :'.format(matrice))
print('  vp1 = {}'.format(valProp[0]))
print('  vp2 = {}'.format(valProp[1]))
# Out:
# Eigenvalues of the matrix [[1, 2], [3, 4]] :
#   vp1 = -0.3722813232690143
#   vp2 = 5.372281323269014

# %%
# To be completed to determine the nature of the critical points of f1

# List of critical points of f1 found analytically
crit_f1 = [(-1, -2), (-1,  2), (1, -2), (1,  2)]

for (x, y) in crit_f1:
    # Calculate the Hessian matrix at (x, y)
    matrice = d2f1(x, y)
    
    # Calculate the eigenvalues of the Hessian matrix
    valProp = np.linalg.eigvals(matrice)
    
    print(f'Point ({x},{y})')
    print('  Hessian = {}'.format(matrice))
    print('  vp1 = {}'.format(valProp[0]))
    print('  vp2 = {}'.format(valProp[1]))
    
    # Determine the nature of the critical point
    if (valProp[0] > 0) and (valProp[1] > 0):
        nature = 'local minimum'
    elif (valProp[0] < 0) and (valProp[1] < 0):
        nature = 'local maximum'
    else:
        nature = 'saddle point'
        
    print('  Nature : {}\n'.format(nature))
# Out:
# Point (-1,-2)
#   Hessian = [[ -6   0]
#  [  0 -12]]
#   vp1 = -6.0
#   vp2 = -12.0
#   Nature : local maximum
#
# Point (-1,2)
#   Hessian = [[-6  0]
#  [ 0 12]]
#   vp1 = -6.0
#   vp2 = 12.0
#   Nature : saddle point
#
# Point (1,-2)
#   Hessian = [[  6   0]
#  [  0 -12]]
#   vp1 = 6.0
#   vp2 = -12.0
#   Nature : saddle point
#
# Point (1,2)
#   Hessian = [[ 6  0]
#  [ 0 12]]
#   vp1 = 6.0
#   vp2 = 12.0
#   Nature : local minimum

# %% [markdown]
# 3.5 Redo questions 3.2, 3.3, and 3.4 for the function $f_2$ from exercise 1.

# %%
# Exercise 3.5 - Determine the nature of the critical points of f2

# Gradient of f2
def df2(x, y):
    df_dx = 3*x**2 - 12*y
    df_dy = -12*x + 24*y**2
    return np.array([df_dx, df_dy])

# Hessian of f2
def d2f2(x, y):
    d2f_dxdx = 6*x
    d2f_dxdy = -12
    d2f_dydx = -12
    d2f_dydy = 48*y
    return np.array([[d2f_dxdx, d2f_dxdy],
                     [d2f_dydx, d2f_dydy]])

# Critical points of f2 found analytically
crit_f2 = [(0, 0), (2, 1)]

for (x, y) in crit_f2:
    # Check gradient
    grad = df2(x, y)
    
    # Calculate the Hessian matrix at (x, y)
    matrice = d2f2(x, y)
    
    # Eigenvalues of the Hessian
    valProp = np.linalg.eigvals(matrice)
    
    print(f'Point ({x},{y})')
    print('  Gradient = {}'.format(grad))
    print('  Hessian = {}'.format(matrice))
    print('  vp1 = {}'.format(valProp[0]))
    print('  vp2 = {}'.format(valProp[1]))
    
    # Nature of the critical point
    det = np.linalg.det(matrice)
    tr = np.trace(matrice)
    if det > 0 and tr > 0:
        nature = 'local minimum'
    elif det > 0 and tr < 0:
        nature = 'local maximum'
    else:
        nature = 'saddle point'
        
    print('  Nature : {}\n'.format(nature))
# Out:
# Point (0,0)
#   Gradient = [0 0]
#   Hessian = [[  0 -12]
#  [-12   0]]
#   vp1 = 11.999999999999998
#   vp2 = -12.000000000000004
#   Nature : saddle point
#
# Point (2,1)
#   Gradient = [0 0]
#   Hessian = [[ 12 -12]
#  [-12  48]]
#   vp1 = 8.366692347216066
#   vp2 = 51.633307652783934
#   Nature : local minimum

# %%
plt.figure(figsize=(6,6))
plt.contour(x2d, y2d, f2(x2d, y2d), 21)
plt.title("Contour Lines of f2 with Critical Points")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.axis('square')

for (x, y) in crit_f2:
    plt.plot(x, y, 'ro')
    plt.text(x+0.15, y+0.15, f"({x},{y})", color='red')

plt.show()
